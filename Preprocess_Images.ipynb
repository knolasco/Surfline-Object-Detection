# %% [markdown]
# <a href="https://colab.research.google.com/github/knolasco/Surfline-Object-Detection/blob/main/Preprocess_Images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from PIL import Image

# %%
# %%bash
# mkdir images
# # add the images to test
# Out:
# mkdir: cannot create directory ‘images’: File exists

# %%
IMG_PATH = '/content/images/'

# %%
img_file = Image.open(IMG_PATH + 'img566.JPG')
img_file = img_file.convert('1')
plt.imshow(img_file)
img_file.save(IMG_PATH + 'img566.JPG')

# %%
img = Image.open(IMG_PATH + 'img566.JPG')
plt.imshow(img_file)

# %%
from PIL import ImageEnhance

img = Image.open(IMG_PATH + 'img567.JPG')
enhancer = ImageEnhance.Contrast(img)
img_enhanced = enhancer.enhance(1.75)
img_final = img_enhanced.convert('1')
plt.figure(figsize = (11,9))
plt.imshow(img_final)

# %%
img_np = np.array(img_final)
img_np = img_np.
# Out:
# PIL.Image.Image
